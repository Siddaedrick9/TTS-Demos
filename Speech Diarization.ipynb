# %%
pip install pyannote.audio torch

# %%
from pyannote.audio import Pipeline

# Initialize the diarization pipeline with a pretrained model
pipeline = Pipeline.from_pretrained("pyannote/speaker-diarization")

# Path to the .wav audio file
audio_file_path = "/content/Orville 06_1.wav"
# Out:
# Could not download 'pyannote/speaker-diarization' pipeline.
# It might be because the pipeline is private or gated so make
# sure to authenticate. Visit https://hf.co/settings/tokens to
# create your access token and retry with:
#
#    >>> Pipeline.from_pretrained('pyannote/speaker-diarization',
#    ...                          use_auth_token=YOUR_AUTH_TOKEN)
#
# If this still does not work, it might be because the pipeline is gated:
# visit https://hf.co/pyannote/speaker-diarization to accept the user conditions.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# ...

# %%
pip install pyannote.audio

# %%
from pyannote.audio import Pipeline


# Initialize the diarization pipeline with a pretrained model
pipeline = Pipeline.from_pretrained("pyannote/speaker-diarization")

# Path to the .wav audio file
audio_file_path = "/content/Orville 06_1.wav"
# Replace 'YOUR_AUTH_TOKEN' with your actual Hugging Face token
auth_token = "YOUR_AUTH_TOKEN"

# Initialize the diarization pipeline with a pretrained model
pipeline = Pipeline.from_pretrained("pyannote/speaker-diarization-3.1", use_auth_token=auth_token)

# Path to the .wav audio file /content/Orville 06_1.wav
audio_file_path = "/content/Orville 06_1.wav"

# Apply the pipeline to the audio file for speaker diarization
diarization = pipeline({"uri": "file", "audio": audio_file_path})

# Display the diarization result
for turn, _, speaker in diarization.itertracks(yield_label=True):
    print(f"Speaker {speaker} speaks from {turn.start:.1f} to {turn.end:.1f} seconds.")
# Out:
# config.yaml:   0%|          | 0.00/469 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/5.91M [00:00<?, ?B/s]
# config.yaml:   0%|          | 0.00/399 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/26.6M [00:00<?, ?B/s]
# config.yaml:   0%|          | 0.00/221 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/models/blocks/pooling.py:104: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at ../aten/src/ATen/native/ReduceOps.cpp:1823.)
#   std = sequences.std(dim=-1, correction=1)
# Speaker SPEAKER_01 speaks from 6.8 to 10.5 seconds.
# Speaker SPEAKER_01 speaks from 10.9 to 22.9 seconds.
# Speaker SPEAKER_01 speaks from 23.5 to 25.3 seconds.
# Speaker SPEAKER_01 speaks from 26.1 to 26.5 seconds.
# Speaker SPEAKER_01 speaks from 27.0 to 31.2 seconds.
# Speaker SPEAKER_01 speaks from 31.6 to 32.0 seconds.
# ...

# %%
from pyannote.audio import Pipeline

# Replace 'YOUR_AUTH_TOKEN' with your actual Hugging Face token
auth_token = "YOUR_AUTH_TOKEN"

# Initialize the diarization pipeline with a pretrained model
pipeline1 = Pipeline.from_pretrained("pyannote/speaker-diarization-3.1", use_auth_token=auth_token)

# Path to the .wav audio file /content/Orville 06_1.wav
audio_file_path = "/content/Maximilian 03_1.wav"

# Apply the pipeline to the audio file for speaker diarization
diarization1 = pipeline1({"uri": "file", "audio": audio_file_path})

# Display the diarization result
for turn, _, speaker in diarization1.itertracks(yield_label=True):
    print(f"Speaker {speaker} speaks from {turn.start:.1f} to {turn.end:.1f} seconds.")
# Out:
# /usr/local/lib/python3.10/dist-packages/pyannote/audio/models/blocks/pooling.py:104: UserWarning: std(): degrees of freedom is <= 0. Correction should be strictly less than the reduction factor (input numel divided by output numel). (Triggered internally at ../aten/src/ATen/native/ReduceOps.cpp:1823.)
#   std = sequences.std(dim=-1, correction=1)
# Speaker SPEAKER_01 speaks from 34.5 to 34.9 seconds.
# Speaker SPEAKER_01 speaks from 36.5 to 38.1 seconds.
# Speaker SPEAKER_03 speaks from 42.4 to 44.0 seconds.
# Speaker SPEAKER_01 speaks from 44.5 to 45.6 seconds.
# Speaker SPEAKER_03 speaks from 46.2 to 47.3 seconds.
# Speaker SPEAKER_02 speaks from 47.3 to 47.3 seconds.
# Speaker SPEAKER_01 speaks from 48.6 to 49.2 seconds.
# Speaker SPEAKER_01 speaks from 50.0 to 50.3 seconds.
# Speaker SPEAKER_02 speaks from 51.0 to 51.3 seconds.
# Speaker SPEAKER_02 speaks from 52.2 to 54.2 seconds.
# Speaker SPEAKER_02 speaks from 55.0 to 56.0 seconds.
# ...

# %%
# prompt: generate subtitles for this audio
#Transcribe and also TTS


#Transcribe and also TTS
#Transcribe and also TTS
#Transcribe and also TTS
#Transcribe and also TTS
#Transcribe and also TTS


from pyannote.audio import Pipeline
import whisper

# Initialize the whisper model
model = whisper.load_model("base")

# Path to the .wav audio file
audio_file_path = "/content/Orville 06_1.wav"

# Transcribe the audio using whisper
result = model.transcribe(audio_file_path)

# Initialize the diarization pipeline with a pretrained model
# Replace 'YOUR_AUTH_TOKEN' with your actual Hugging Face token
auth_token = "YOUR_AUTH_TOKEN"
pipeline = Pipeline.from_pretrained("pyannote/speaker-diarization-3.1", use_auth_token=auth_token)

# Apply the pipeline to the audio file for speaker diarization
diarization = pipeline({"uri": "file", "audio": audio_file_path})

# Create subtitles
subtitles = []
for segment in result["segments"]:
    start_time = segment["start"]
    end_time = segment["end"]
    text = segment["text"]

    for turn, _, speaker in diarization.itertracks(yield_label=True):
        if start_time >= turn.start and end_time <= turn.end:
            subtitles.append(f"{start_time:.2f} --> {end_time:.2f}\nSpeaker {speaker}: {text}\n")
            break  # Assign text to the first matching speaker turn

# Print the generated subtitles
for subtitle in subtitles:
    print(subtitle)


# Process the second audio file ("Maximilian 03_1.wav") similarly

audio_file_path = "/content/Maximilian 03_1.wav"
result = model.transcribe(audio_file_path)
diarization1 = pipeline({"uri": "file", "audio": audio_file_path})
subtitles1 = []

for segment in result["segments"]:
    start_time = segment["start"]
    end_time = segment["end"]
    text = segment["text"]
    for turn, _, speaker in diarization1.itertracks(yield_label=True):
      if start_time >= turn.start and end_time <= turn.end:
        subtitles1.append(f"{start_time:.2f} --> {end_time:.2f}\nSpeaker {speaker}: {text}\n")
        break

for subtitle in subtitles1:
    subtitle

# %%
#Transcribe and also TTS
